# %% [markdown]
# <a href="https://colab.research.google.com/github/Shivani11032006/ml_with_flask/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd
uploaded=files.upload()
shivani=list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-a17305c2-4b70-4f4a-878b-e6bfc77955cd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a17305c2-4b70-4f4a-878b-e6bfc77955cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Out:
#    Customer_id   Product
# 0            1    Tablet
# 1            2     Books
# 2            3   Station
# 3            4        TV

# %%
import pandas as pd
import numpy as np
#data frame2
dict2 ={'Customer_id':[1,2,3,4,5,6],'State':['Telangana','Telangana','Tripura','Goa',' Sikkim','Tamil Nadu']}
df2 = pd.DataFrame(dict2)
df2
# Out:
#    Customer_id       State
# 0            1   Telangana
# 1            2   Telangana
# 2            3     Tripura
# 3            4         Goa
# 4            5      Sikkim
# 5            6  Tamil Nadu

# %%
inner_join_df = pd.merge(df1, df2, on='Customer_id', how='inner')
inner_join_df
# Out:
#    Customer_id   Product      State
# 0            1    Tablet  Telangana
# 1            2     Books  Telangana
# 2            3   Station    Tripura
# 3            4        TV        Goa

# %%
outer_join_df = pd.merge(df1, df2, on='Customer_id', how='outer')
outer_join_df
# Out:
#    Customer_id   Product       State
# 0            1    Tablet   Telangana
# 1            2     Books   Telangana
# 2            3   Station     Tripura
# 3            4        TV         Goa
# 4            5       NaN      Sikkim
# 5            6       NaN  Tamil Nadu

# %%
#create two data frames, in first df column name with product and customer name,in second df price and product.in both df product name should be matched.in both df try to implement left,right,inner,outer.
import pandas as pd
import numpy as np
#data frame3
dict3 ={'Product':['Tablet','Books',' Station','TV','PEN'],'Customer_name':['Shivani','Thanishka','Vandana','Rajini','Vidya']}
df3 = pd.DataFrame(dict3)
df3
# Out:
#     Product Customer_name
# 0    Tablet       Shivani
# 1     Books     Thanishka
# 2   Station       Vandana
# 3        TV        Rajini
# 4       PEN         Vidya

# %%
import pandas as pd
import numpy as np
#data frame4
dict4 ={'Product':['Tablet','Books',' Station','TV'],'Price':[100,1000,20000000,45000]}
df4 = pd.DataFrame(dict4)
df4
# Out:
#     Product     Price
# 0    Tablet       100
# 1     Books      1000
# 2   Station  20000000
# 3        TV     45000

# %%
outer_join_df = pd.merge(df3, df4, on='Product', how='outer')
outer_join_df
# Out:
#     Product Customer_name       Price
# 0   Station       Vandana  20000000.0
# 1     Books     Thanishka      1000.0
# 2       PEN         Vidya         NaN
# 3        TV        Rajini     45000.0
# 4    Tablet       Shivani       100.0

# %%
inner_join_df = pd.merge(df3, df4, on='Product', how='inner')
inner_join_df
# Out:
#     Product Customer_name     Price
# 0    Tablet       Shivani       100
# 1     Books     Thanishka      1000
# 2   Station       Vandana  20000000
# 3        TV        Rajini     45000

# %%
right_join_df = pd.merge(df3, df4, on='Product', how='right')
right_join_df
# Out:
#     Product Customer_name     Price
# 0    Tablet       Shivani       100
# 1     Books     Thanishka      1000
# 2   Station       Vandana  20000000
# 3        TV        Rajini     45000

# %%
left_join_df = pd.merge(df3, df4, on='Product', how='left')
left_join_df
# Out:
#     Product Customer_name       Price
# 0    Tablet       Shivani       100.0
# 1     Books     Thanishka      1000.0
# 2   Station       Vandana  20000000.0
# 3        TV        Rajini     45000.0
# 4       PEN         Vidya         NaN
